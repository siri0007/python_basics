# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
mydata = pd.read_csv('dataset1.csv')

# %%
mydata
# Out:
#      gender  age  education  occupation  part of city  income  visits  \
# 0         2   49          4           3             3   53121       4
# 1         1   40          2           4             3   38541       3
# 2         1   29          2           4             1   51353       3
# 3         2   26          5           1             1   46069       4
# 4         2   36          4           2             1   43548       4
# ..      ...  ...        ...         ...           ...     ...     ...
# 245       1   47          3           1             3   59326       3
# 246       2   38          2           2             1   49077       3
# 247       1   41          4           4             3   43761       3
# 248       1   40          4           2             2   39968       3
# 249       2   29          4           2             3   60559       2
#
#      typepurch  amountspent  supermarketrating
# 0            3         3714                  1
# ...

# %%
sns.distplot(mydata['age'])
# Out:
# D:\python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='age', ylabel='Density'>

# %% [markdown]
# in y axis the probability of occurance

# %%
sns.distplot(mydata['income'])
# Out:
# D:\python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='income', ylabel='Density'>

# %%
sns.distplot(mydata['amountspent'])
# Out:
# D:\python\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='amountspent', ylabel='Density'>

# %%
sns.scatterplot(mydata['income'],mydata['amountspent'])
# Out:
# D:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='income', ylabel='amountspent'>

# %% [markdown]
# in x axis=income y axis= amount spent (for scatter plot both the data should be continuous one should ne be continuous & one should not be categorical )

# %%
sns.jointplot(mydata['income'],mydata['amountspent'])
# Out:
# D:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# this joint polt combines scatter & histogram

# %%
sns.pairplot(mydata[['age','amountspent','income']])

# %% [markdown]
# this plot can be used to find which variable is highly correlated, also

# %%
sns.boxplot(mydata['age'])
# Out:
# D:\python\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='age'>

# %%
ax=sns.boxplot(x="gender",y="supermarketrating",data=mydata)

# %% [markdown]
# for this x maybe categorical & y should be continuous

# %%
ax=sns.boxplot(x="part of city",y="supermarketrating",data=mydata)

# %%
ax=sns.boxplot(x="education",y="supermarketrating",data=mydata)

# %% [markdown]
# in 3 the min is 1st quartile and max is 3rd quartile because range is 1 to 5

# %%
crosstab=pd.cross(df['education'],df['supermarketrating'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14772/3811784435.py in <module>
# ----> 1 crosstab=pd.cross(df['education'],df['supermarketrating'])
#
# D:\python\lib\site-packages\pandas\__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'cross'

# %%
sns.lmplot(x='income',y='amountspent',hue='gender',data=mydata)

# %% [markdown]
# the string can be given in a single quoter or double it doesnot matter in python

# %% [markdown]
# the slope for female(blue) is little steeper thsn male
# 1 unit of increase in income makes male to spent less but for female

# %%
sns.lmplot(x='age',y='amountspent',hue='gender',data=mydata)

# %% [markdown]
# this is called moderation effect ("presence of gender making to behave differently")
# aged male are spending less and female are spending more

# %%
import matplotlib.pyplot as plt

# %%
cardheko = pd.read_csv('cardheko.csv')

# %%
cardheko.head() #this syntax is to check whether the data is being read properly or not if not it will throw some error
# Out:
#    year_m  Mileage Km/l seller_type         owner  selling_price
# 0    2007            15  Individual  Second Owner          60000
# 1    2007            16  Individual   Third Owner         135000
# 2    2012            18  Individual   First Owner         600000
# 3    2017            16  Individual   Third Owner         250000
# 4    2014            16  Individual   First Owner         450000

# %%
cardheko['selling_price'].describe()
# Out:
# count    4.340000e+03
# mean     5.041273e+05
# std      5.785487e+05
# min      2.000000e+04
# 25%      2.087498e+05
# 50%      3.500000e+05
# 75%      6.000000e+05
# max      8.900000e+06
# Name: selling_price, dtype: float64

# %%
cardheko['Mileage Km/l'].describe()
# Out:
# count    4340.000000
# mean       18.017742
# std         3.610490
# min         7.000000
# 25%        15.000000
# 50%        18.000000
# 75%        21.000000
# max        29.000000
# Name: Mileage Km/l, dtype: float64

# %%
cardheko.info() # to get the data types of each data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4340 entries, 0 to 4339
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   year_m         4340 non-null   int64
#  1   Mileage Km/l   4340 non-null   int64
#  2   seller_type    4340 non-null   object
#  3   owner          4340 non-null   object
#  4   selling_price  4340 non-null   int64
# dtypes: int64(3), object(2)
# memory usage: 169.7+ KB

# %%
sns.jointplot(x="year_m",y="selling_price",data=cardheko)

# %% [markdown]
# the car below 2 lakhs has been sold much more but here we havent removed outliers so it may contain some error

# %%
sns.jointplot(x="Mileage Km/l",y="selling_price",data=cardheko)

# %%
import statsmodels.api as sm
from statsmodels.formula.api import ols #ordinary lease square

# %%
model1=ols('selling_price~year_m',data=cardheko).fit()

# %%
model1.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:          selling_price   R-squared:                       0.172
# Model:                            OLS   Adj. R-squared:                  0.171
# Method:                 Least Squares   F-statistic:                     898.1
# Date:                Tue, 10 May 2022   Prob (F-statistic):          1.65e-179
# Time:                        09:36:59   Log-Likelihood:                -63334.
# No. Observations:                4340   AIC:                         1.267e+05
# Df Residuals:                    4338   BIC:                         1.267e+05
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept  -1.144e+08   3.83e+06    -29.837      0.000   -1.22e+08   -1.07e+08
# ...

# %%
cardheko.head()
# Out:
#    year_m  Mileage Km/l seller_type         owner  selling_price
# 0    2007            15  Individual  Second Owner          60000
# 1    2007            16  Individual   Third Owner         135000
# 2    2012            18  Individual   First Owner         600000
# 3    2017            16  Individual   Third Owner         250000
# 4    2014            16  Individual   First Owner         450000

# %%
cardheko['year_m'].describe()
# Out:
# count    4340.000000
# mean     2013.079724
# std         4.198476
# min      1992.000000
# 25%      2011.000000
# 50%      2014.000000
# 75%      2016.000000
# max      2019.000000
# Name: year_m, dtype: float64

# %%
cardheko['Mileage Km/l'].describe()
# Out:
# count    4340.000000
# mean       18.017742
# std         3.610490
# min         7.000000
# 25%        15.000000
# 50%        18.000000
# 75%        21.000000
# max        29.000000
# Name: Mileage Km/l, dtype: float64

# %%
cardheko['selling_price'].describe()
# Out:
# count    4.340000e+03
# mean     5.041273e+05
# std      5.785487e+05
# min      2.000000e+04
# 25%      2.087498e+05
# 50%      3.500000e+05
# 75%      6.000000e+05
# max      8.900000e+06
# Name: selling_price, dtype: float64
